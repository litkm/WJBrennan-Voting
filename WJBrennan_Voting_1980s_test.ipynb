# %% [markdown]
# <a href="https://colab.research.google.com/github/litkm/WJBrennan-Voting/blob/main/WJBrennan_Voting_1980s_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Inspiration for this project came from lesson 8 of Prof. Wolfgang Alschner's course, Data Science for Lawyers (https://www.datascienceforlawyers.org/learning-resources/lesson-8/)
#Model adapted from the classification project in unit 4 of Codecademy's skills path, Build Deep Learning Models with TensorFlow

import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from collections import Counter
from sklearn.compose import ColumnTransformer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
from sklearn.metrics import classification_report
from tensorflow.keras.utils import to_categorical
import numpy as np

dataset = 'https://raw.githubusercontent.com/litkm/WJBrennan-Voting/main/WJBrennan_voting.csv'
dataset = pd.read_csv(dataset)

#print(dataset.head())
#print(dataset.describe())
print(dataset.info())

print('Classes and number of values in the dataset',Counter(dataset['vote']))

y = dataset['vote']
x = dataset[['term', 'petitioner', 'respondent', 'jurisdiction', 'caseOrigin', 'caseSource', 'certReason', 'issue', 'issueArea']]

#y = pd.get_dummies(y) #is this necessary or do we process it later?

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

columns_for_standard = ['term', 'petitioner', 'respondent', 'jurisdiction', 'caseOrigin', 'caseSource', 'certReason', 'issue', 'issueArea']

ct = ColumnTransformer([('numeric', StandardScaler(), columns_for_standard)])

X_train = ct.fit_transform(X_train) 
X_test = ct.transform(X_test)

le = LabelEncoder()
Y_train = le.fit_transform(Y_train.astype(str))
Y_test = le.transform(Y_test.astype(str))

Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

model = Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(10, activation='relu'))
model.add(Dense(2, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, Y_train, epochs=100, batch_size=8, verbose=1)

loss, acc = model.evaluate(X_test, Y_test, verbose=0)
print("Loss:", loss, "Accuracy:", acc)

y_estimate = model.predict(X_test, verbose=0)
y_estimate = np.argmax(y_estimate, axis=1)
y_true = np.argmax(Y_test, axis=1)
print(classification_report(y_true, y_estimate))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   term          4746 non-null   int64
#  1   petitioner    4746 non-null   int64
#  2   respondent    4746 non-null   int64
#  3   jurisdiction  4746 non-null   int64
#  4   caseOrigin    4746 non-null   int64
#  5   caseSource    4746 non-null   int64
#  6   certReason    4746 non-null   int64
#  7   issue         4746 non-null   int64
#  8   issueArea     4746 non-null   int64
#  9   vote          4746 non-null   object
# dtypes: int64(9), object(1)
# memory usage: 370.9+ KB
# None
# Classes and number of values in the dataset Counter({'majority': 3683, 'dissent': 1063})
# Epoch 1/100
# 416/416 [==============================] - 0s 982us/step - loss: 0.5350 - accuracy: 0.7616
# Epoch 2/100
# 416/416 [==============================] - 0s 967us/step - loss: 0.4772 - accuracy: 0.7854
# Epoch 3/100
# 416/416 [==============================] - 0s 997us/step - loss: 0.4715 - accuracy: 0.7848
# Epoch 4/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4677 - accuracy: 0.7920
# Epoch 5/100
# 416/416 [==============================] - 0s 991us/step - loss: 0.4669 - accuracy: 0.7884
# Epoch 6/100
# 416/416 [==============================] - 0s 993us/step - loss: 0.4656 - accuracy: 0.7857
# Epoch 7/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4642 - accuracy: 0
100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4545 - accuracy: 0.7860
# Epoch 43/100
# 416/416 [==============================] - 0s 966us/step - loss: 0.4537 - accuracy: 0.7908
# Epoch 44/100
# 416/416 [==============================] - 0s 998us/step - loss: 0.4543 - accuracy: 0.7881
# Epoch 45/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4539 - accuracy: 0.7905
# Epoch 46/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4538 - accuracy: 0.7908
# Epoch 47/100
# 416/416 [==============================] - 0s 985us/step - loss: 0.4540 - accuracy: 0.7872
# Epoch 48/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4539 - accuracy: 0.7872
# Epoch 49/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4543 - accuracy: 0.7821
# Epoch 50/100
# 416/416 [==============================] - 0s 959us/step - loss: 0.4533 - accuracy: 0.7905
# Epoch 51/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4531 - accuracy: 0.7860
# Epoch 52/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4537 - accuracy: 0.7857
# Epoch 53/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4537 - accuracy: 0.7881
# Epoch 54/100
# 416/416 [==============================] - 0s 994us/step - loss: 0.4530 - accuracy: 0.7896
# Epoch 55/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4533 - accuracy: 0.7917
# Epoch 56/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4535 - accuracy: 0.7914
# Epoch 57/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4531 - accuracy: 0.7887
# Epoch 58/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4535 - accuracy: 0.7887
# Epoch 59/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4530 - accuracy: 0.7896
# Epoch 60/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4535 - accuracy: 0.7872
# Epoch 61/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4532 - accuracy: 0.7866
# Epoch 62/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4532 - accuracy: 0.7875
# Epoch 63/100
# 416/416 [==============================] - 0s 962us/step - loss: 0.4528 - accuracy: 0.7866
# Epoch 64/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4530 - accuracy: 0.7872
# Epoch 65/100
# 416/416 [==============================] - 0s 967us/step - loss: 0.4530 - accuracy: 0.7860
# Epoch 66/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4526 - accuracy: 0.7875
# Epoch 67/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4533 - accuracy: 0.7869
# Epoch 68/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4526 - accuracy: 0.7890
# Epoch 69/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4526 - accuracy: 0.7869
# Epoch 70/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4531 - accuracy: 0.7887
# Epoch 71/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4525 - accuracy: 0.7863
# Epoch 72/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4528 - accuracy: 0.7875
# Epoch 73/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4526 - accuracy: 0.7890
# Epoch 74/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4517 - accuracy: 0.7908
# Epoch 75/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4525 - accuracy: 0.7872
# Epoch 76/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4516 - accuracy: 0.7905
# Epoch 77/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4528 - accuracy: 0.7920
# Epoch 78/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4524 - accuracy: 0.7872
# Epoch 79/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4525 - accuracy: 0.7899
# Epoch 80/100
# 416/416 [==============================] - 0s 991us/step - loss: 0.4521 - accuracy: 0.7887
# Epoch 81/100
# 416/416 [==============================] - 0s 961us/step - loss: 0.4526 - accuracy: 0.7902
# Epoch 82/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4523 - accuracy: 0.7908
# Epoch 83/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4518 - accuracy: 0.7896
# Epoch 84/100
# 416/416 [==============================] - 0s 983us/step - loss: 0.4523 - accuracy: 0.7920
# Epoch 85/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4523 - accuracy: 0.7887
# Epoch 86/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4521 - accuracy: 0.7947
# Epoch 87/100
# 416/416 [==============================] - 0s 997us/step - loss: 0.4525 - accuracy: 0.7878
# Epoch 88/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4518 - accuracy: 0.7842
# Epoch 89/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4516 - accuracy: 0.7878
# Epoch 90/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4521 - accuracy: 0.7875
# Epoch 91/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4519 - accuracy: 0.7899
# Epoch 92/100
# 416/416 [==============================] - 0s 999us/step - loss: 0.4522 - accuracy: 0.7881
# Epoch 93/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4516 - accuracy: 0.7899
# Epoch 94/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4521 - accuracy: 0.7881
# Epoch 95/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4517 - accuracy: 0.7920
# Epoch 96/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4520 - accuracy: 0.7878
# Epoch 97/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4516 - accuracy: 0.7875
# Epoch 98/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4515 - accuracy: 0.7863
# Epoch 99/100
# 416/416 [==============================] - 0s 990us/step - loss: 0.4515 - accuracy: 0.7923
# Epoch 100/100
# 416/416 [==============================] - 0s 1ms/step - loss: 0.4510 - accuracy: 0.7914
# Loss: 0.4765138030052185 Accuracy: 0.7808988690376282
#               precision    recall  f1-score   support
#
#            0       0.61      0.13      0.22       327
#            1       0.79      0.97      0.87      1097
#
#     accuracy                           0.78      1424
#    macro avg       0.70      0.55      0.54      1424
# weighted avg       0.75      0.78      0.72      1424
